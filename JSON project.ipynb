# %%
import pandas as pd

# %%
import json

# %%
from pandas.io.json import json_normalize

# %%
with open("world_bank_projects.json") as json_file:
    json_data = json.load(json_file)

# %%
df = json_normalize(json_data)

# %%
q1 = df['countryname'].value_counts().head(n=10)

# %%
q1
# Out:
# Republic of Indonesia              19
# People's Republic of China         19
# Socialist Republic of Vietnam      17
# Republic of India                  16
# Republic of Yemen                  13
# People's Republic of Bangladesh    12
# Nepal                              12
# Kingdom of Morocco                 12
# Africa                             11
# Republic of Mozambique             11
# Name: countryname, dtype: int64

# %%
dftheme = json_normalize(json_data,'mjtheme_namecode')

# %%
dftheme
# Out:
#      code                                          name
# 0       8                             Human development
# 1      11
# 2       1                           Economic management
# 3       6         Social protection and risk management
# 4       5                         Trade and integration
# 5       2                      Public sector governance
# 6      11  Environment and natural resources management
# 7       6         Social protection and risk management
# 8       7                   Social dev/gender/inclusion
# 9       7                   Social dev/gender/inclusion
# 10      5                         Trade and integration
# 11      4      Financial and private sector development
# 12      6         Social protection and risk management
# 13      6
# 14      2                      Public sector governance
# 15      4      Financial and private sector development
# 16     11  Environment and natural resources management
# 17      8
# ...

# %%
dftheme['code'].value_counts()
# Out:
# 11    250
# 10    216
# 8     210
# 2     199
# 6     168
# 4     146
# 7     130
# 5      77
# 9      50
# 1      38
# 3      15
# Name: code, dtype: int64

# %%
q2=dftheme['code'].value_counts().head(n=10)

# %%
q2
# Out:
# 11    250
# 10    216
# 8     210
# 2     199
# 6     168
# 4     146
# 7     130
# 5      77
# 9      50
# 1      38
# Name: code, dtype: int64

# %%
dftheme.loc[dftheme['code'].str.contains('1',case=True),'name']='Economic management'
dftheme.loc[dftheme['code'].str.contains('11',case=False),'name']='Environment and natural resources management'
dftheme.loc[dftheme['code'].str.contains('10',case=True),'name']='Rural development'
dftheme.loc[dftheme['code'].str.contains('8',case=True),'name']='Human development'
dftheme.loc[dftheme['code'].str.contains('2',case=True),'name']='Public sector governance'
dftheme.loc[dftheme['code'].str.contains('6',case=True),'name']='Social protection and risk management'
dftheme.loc[dftheme['code'].str.contains('4',case=True),'name']='Financial and private sector development'
dftheme.loc[dftheme['code'].str.contains('7',case=True),'name']='Social dev/gender/inclusion'
dftheme.loc[dftheme['code'].str.contains('5',case=True),'name']='Trade and integration'
dftheme.loc[dftheme['code'].str.contains('9',case=True),'name']='Urban development'
dftheme.loc[dftheme['code'].str.contains('3',case=True),'name']='Rule of law'

# %%
dftheme
# Out:
#      code                                          name
# 0       8                             Human development
# 1      11  Environment and natural resources management
# 2       1                           Economic management
# 3       6         Social protection and risk management
# 4       5                         Trade and integration
# 5       2                      Public sector governance
# 6      11  Environment and natural resources management
# 7       6         Social protection and risk management
# 8       7                   Social dev/gender/inclusion
# 9       7                   Social dev/gender/inclusion
# 10      5                         Trade and integration
# 11      4      Financial and private sector development
# 12      6         Social protection and risk management
# 13      6         Social protection and risk management
# 14      2                      Public sector governance
# 15      4      Financial and private sector development
# ...

# %%
dftheme['name'].value_counts()
# Out:
# Environment and natural resources management    250
# Rural development                               216
# Human development                               210
# Public sector governance                        199
# Social protection and risk management           168
# Financial and private sector development        146
# Social dev/gender/inclusion                     130
# Trade and integration                            77
# Urban development                                50
# Economic management                              38
# Rule of law                                      15
# Name: name, dtype: int64
